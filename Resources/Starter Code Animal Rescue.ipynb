# %%
pip install petpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import petpy
import pandas

pf=petpy.Petfinder(key="8vrj4YRpIYvkF3DfcbWw7LEg8ZLwr6t17XShxvgXy3LFGoBhlI", secret = "qC0gxHq22Ak7dp4nHvJeHjJ2gKkTzyssCWcJedsH")
output_data_file ="/users/rebeccatast/desktop/Animal-Adoptions/Resources/texas_animal_shelters.csv"

# %%
animal_types = pf.animal_types()
for animal in animal_types ["types"]:
    print(animal["name"], "\n", animal ["coats"])
# Out:
# Dog
#  ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly']
# Cat
#  ['Hairless', 'Short', 'Medium', 'Long']
# Rabbit
#  ['Short', 'Long']
# Small & Furry
#  ['Hairless', 'Short', 'Long']
# Horse
#  []
# Bird
#  []
# Scales, Fins & Other
#  []
# Barnyard
#  ['Short', 'Long']

# %%
tx_orgs = pf.organizations(location = "Austin, TX", distance=500, sort = "distance", pages=None, return_df=True)
tx_orgs.shape
tx_orgs.head(15)
# Out:
# /Users/rebeccatast/opt/anaconda3/lib/python3.8/site-packages/petpy/api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])
#         id                                         name  \
# 0   TX1148                          Small Chance Rescue
# 1    TX241                                   Wee Rescue
# 2    TX192                           GALT Central Texas
# 3   TX1357                         Purrfect Pals Rescue
# 4   TX1402                                  Love-A-Bull
# 5    TX500                                 Hound Rescue
# 6   TX1334                        Austin Siamese Rescue
# 7    TX562               Central Texas Dachshund Rescue
# 8    TX365  Cocker Spaniel Rescue of Austin/San Antonio
# 9    TX514                         Austin Animal Center
# 10   TX727                       Vision Hills Sanctuary
# 11  TX2339                  New Hope Animal Rescue NFP
# ...

# %%
dogs = pf.animals(animal_type = "dog",location = "TX",status = "adopted", return_df = True)
dogs.head(100)
# Out:
# /Users/rebeccatast/opt/anaconda3/lib/python3.8/site-packages/petpy/api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])
#           id organization_id  \
# 0   49741266          TX1655
# 1   49741259          TX1655
# 2   49741199          TX1655
# 3   49741138          TX1655
# 4   49716628           TX180
# 5   49716629           TX180
# 6   49716627           TX180
# 7   49716626           TX180
# 8   49715795          TX1868
# 9   49710630           TX247
# 10  49707950            TX95
# 11  49707844            TX95
# 12  49704997          TX1655
# 13  49704953          TX1655
# 14  49704918          TX1655
# 15  49704839          TX1655
# 16  49704803          TX1655
# 17  49704789          TX1655
# 18  49693084          TX1655
# 19  49692162          TX1655
#
#                                                   url type species    age  \
# ...

# %%
animal_breeds = pf.breeds()
animal_types = pf.animal_types()
dog_breeds =pf.breeds("dog", return_df = True)
dog_breeds.head(500)
# Out:
# /Users/rebeccatast/opt/anaconda3/lib/python3.8/site-packages/petpy/api.py:305: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df_results = df_results.append(json_normalize(result['breeds']))
#                                   name breed
# 0                        Affenpinscher   Dog
# 1                         Afghan Hound   Dog
# 2                     Airedale Terrier   Dog
# 3                               Akbash   Dog
# 4                                Akita   Dog
# ..                                 ...   ...
# 270        Wirehaired Pointing Griffon   Dog
# 271                 Wirehaired Terrier   Dog
# 272  Xoloitzcuintli / Mexican Hairless   Dog
# 273          Yellow Labrador Retriever   Dog
# 274                  Yorkshire Terrier   Dog
#
# [275 rows x 2 columns]
