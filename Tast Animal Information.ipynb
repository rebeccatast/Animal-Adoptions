# %%
pip install petpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import petpy
import pandas

pf=petpy.Petfinder(key="8vrj4YRpIYvkF3DfcbWw7LEg8ZLwr6t17XShxvgXy3LFGoBhlI", secret = "qC0gxHq22Ak7dp4nHvJeHjJ2gKkTzyssCWcJedsH")
output_data_file_amarillo ="/users/rebeccatast/desktop/Animal-Adoptions/Resources/amarillo.csv"
output_data_file_tyler ="/users/rebeccatast/desktop/Animal-Adoptions/Resources/tyler.csv"
output_data_file_san ="/users/rebeccatast/desktop/Animal-Adoptions/Resources/san_angelo.csv"

# %%
dogs_amarillo_df = pf.animals(animal_type = "dog",location = "Amarillo, TX", distance=150, pages =500, return_df = True)
dogs_amarillo_df.head(500)
# Out:
# pages parameter exceeded maximum number of available pages available from the Petfinder API. As a result, the maximum number of pages 15 was returned
#            id  organization_id  \
# 0    49789746           TX1604
# 1    49789726           TX1604
# 2    49789678           TX1604
# 3    49789605           TX1604
# 4    49789533           TX1604
# ..        ...              ...
# 275  44651073           TX1423
# 276  44650933           TX1696
# 277  43728393           TX1423
# 278  43722169           TX2068
# 279  43018260           TX1300
#
#                                                    url type species    age  \
# 0    https://www.petfinder.com/dog/d20-11016-497897...  Dog     Dog   Baby
# 1    https://www.petfinder.com/dog/d20-11015-497897...  Dog     Dog   Baby
# 2    https://www.petfinder.com/dog/d20-11014-497896...  Dog     Dog   Baby
# 3    https://www.petfinder.com/dog/d20-11013-497896...  Dog     Dog   Baby
# ...

# %%
dogs_amarillo_df.to_csv(output_data_file_amarillo, index_label="id")

# %%
dogs_tyler_df = pf.animals(animal_type = "dog",location = "Tyler, TX", distance=150, pages =500, return_df = True)
dogs_tyler_df.head(500)
# Out:
# /Users/rebeccatast/opt/anaconda3/lib/python3.8/site-packages/petpy/api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])
# pages parameter exceeded maximum number of available pages available from the Petfinder API. As a result, the maximum number of pages 183 was returned
#            id  organization_id  \
# 0    49795079            TX671
# 1    49795144            TX209
# 2    49795141            TX236
# 3    49795140            TX236
# 4    49795082            TX209
# ..        ...              ...
# 495  49753119             TX26
# 496  49753005             TX26
# 497  49752982             TX26
# 498  49752912             TX26
# 499  49752833             TX26
#
#                                                    url type species     age  \
# 0    https://www.petfinder.com/dog/eric-the-red-497...  Dog     Dog   Adult
# ...

# %%
dogs_tyler_df.to_csv(output_data_file_tyler, index_label="id")

# %%
dogs_san_angelo_df = pf.animals(animal_type = "dog",location = "San Angelo, TX", distance=150, pages =500, return_df = True)
dogs_san_angelo_df.head(500)
# Out:
# pages parameter exceeded maximum number of available pages available from the Petfinder API. As a result, the maximum number of pages 18 was returned
# /Users/rebeccatast/opt/anaconda3/lib/python3.8/site-packages/petpy/api.py:1049: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   results_df = json_normalize(results[key])
#            id  organization_id  \
# 0    49795186           TX1030
# 1    49795047           TX1030
# 2    49793320             TX95
# 3    49793301            TX364
# 4    49793273             TX95
# ..        ...              ...
# 335  36224279           TX2135
# 336  35999041           TX2135
# 337  32276111           TX1423
# 338  32228086           TX1626
# 339  31869774           TX1626
#
#                                                    url type species     age  \
# 0    https://www.petfinder.com/dog/wendy-49795186/t...  Dog     Dog    Baby
# ...

# %%
dogs_san_angelo_df.to_csv(output_data_file_san, index_label="id")
