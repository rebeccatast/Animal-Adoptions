# %%
#Set Dependencies
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
#Import CSV
csvfile = "Animal-Adoptions/large.csv"

#Read CSV
pet_data = pd.read_csv(csvfile)

# %%
pet_data.head()
# Out:
#        id.1 organization_id    age  gender    size    coat  \
# 0  49774956           TX988   Baby  Female  Medium   Short
# 1  49763712           TX988  Young  Female  Medium   Short
# 2  49763210           TX988  Young  Female  Medium   Short
# 3  49761306           TX988  Young    Male   Large    Long
# 4  49696332           TX988  Young  Female  Medium  Medium
#
#                                                 tags  name_x  \
# 0  ['Playful', 'energetic', 'loving', 'happy', 'l...   Robin
# 1                                                 []    Lulu
# 2                                                 []   Noche
# 3                                                 []  REggie
# 4                                                 []   Gabby
#
#                                          description   status  ...  \
# 0  Have you met… Robin?\n\nRobin comes from a lit...  adopted  ...
# 1  Lulu loves you already — and you’ve only just ...  adopted  ...
# 2  Meet Noche!\n\nLittle Noche is a super sweet a...  adopted  ...
# 3  Rescued with a few other wandering big dogs fr...  adopted  ...
# 4  Gabby is as sweet as her coat is white and wou...  adopted  ...
#
#     colors.primary attributes.spayed_neutered  attributes.house_trained  \
# 0  Apricot / Beige                       True                     False
# 1          Brindle                       True                     False
# 2            Black                       True                     False
# 3            Black                       True                     False
# 4    White / Cream                       True                     False
#
#   special_needs shots_current  contact.address.city  contact.address.postcode  \
# 0         False         False           San Antonio                     78209
# 1         False          True           San Antonio                     78209
# 2         False          True           San Antonio                     78209
# 3         False          True           San Antonio                     78209
# 4         False          True           San Antonio                     78209
#
#    animal_id  organization_id.1       name_y
# 0   49774956              TX988  SNIPSA Inc.
# 1   49763712              TX988  SNIPSA Inc.
# 2   49763210              TX988  SNIPSA Inc.
# 3   49761306              TX988  SNIPSA Inc.
# 4   49696332              TX988  SNIPSA Inc.
#
# [5 rows x 24 columns]

# %%
#Total Number of Dogs
total_dogs = len(pet_data["animal_id"].unique())
print(total_dogs)
# Out:
# 668

# %%
#Check for duplicates
pet_data = pet_data.drop_duplicates(subset=["animal_id"], keep ="last")
print(len(pet_data))
# Out:
# 668

# %%
#Sort All Shelter Information by Gender
true_mf1 = pet_data.loc[:, "gender"]
true_mf2 = true_mf1.value_counts()
true_mf2
# Out:
# Female    339
# Male      329
# Name: gender, dtype: int64

# %%
#Pie Chart Using Pyplot for All Shelter Information by Gender

colors = ["lightcoral","lightskyblue"]

labels = true_mf2.index
sizes = true_mf2.values
explode = (0.1,0)

#Create Pie Chart Using the Above Data

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)

# Create axes which are equal so we have a perfect circle

plt.axis("equal")
plt.show()

# %%
#Pie Chart Using Pandas for All Shelter Information by Gender
colors = ["lightcoral", "lightskyblue"]
explode = [0.1, 0]
true_mf2.plot(kind="pie",shadow = True, colors=colors, explode = explode, startangle=90,figsize=(6,4), autopct='%1.1f%%')
plt.ylabel(" ")
plt.axis("equal")
plt.show()


plt.savefig("Animal-Adoptions/output_data/LargestShelter_Gender.png")

# %%
#Sort All Shelter Information by Dog Size
true_size1 = pet_data.loc[:, "size"]
true_size2 = true_size1.value_counts()
true_size2
# Out:
# Medium    399
# Small     185
# Large      84
# Name: size, dtype: int64

# %%
#Pie Chart Using Pandas for All Shelter Information by Size
colors = ["tomato","cornflowerblue","silver"]
explode = [0.1, 0,0]
true_size2.plot(kind="pie",shadow = True, colors = colors, explode = explode, startangle=90,figsize=(6,4), autopct='%1.1f%%')
plt.title("Dog Sizes")
plt.ylabel(" ")
plt.axis("equal")

plt.savefig("Animal-Adoptions/output_data/LargestShelter_Sizes.png")

plt.show()

# %%
true_age1 = pet_data.loc[:, "age"]
true_age2 = true_age1.value_counts()
true_age2
# Out:
# Baby      404
# Young     229
# Adult      32
# Senior      3
# Name: age, dtype: int64

# %%
#Pie Chart Using Pandas for All Shelter Information by Size
colors = ["tomato","cornflowerblue","silver","gold"]

y_axis = true_age2.values
x_axis = true_age2.index

#Outline the graph
true_age2.plot(kind="bar", facecolor='grey')

#Assemble the graph
plt.xticks(rotation = 90)
plt.title("Dog Ages")
plt.xlabel("Age Groups")
plt.ylabel("Total Count")
plt.show()

plt.savefig("Animal-Adoptions/output_data/LargestShelter_Ages.png")

# %%
# First create a dataframe grouping by the Breed Column
dog_breeds_data = pet_data.groupby("breeds.primary")

dog_breeds_count = dog_breeds_data["breeds.primary"].count()

breed_summary = pd.DataFrame({"Count": dog_breeds_count})

breed_summary.sort_values(["Count"], ascending = False)
# Out:
#                                       Count
# breeds.primary
# Chihuahua                                77
# Labrador Retriever                       68
# Collie                                   45
# Great Pyrenees                           42
# Dachshund                                36
# Hound                                    33
# Shepherd                                 30
# Australian Cattle Dog / Blue Heeler      29
# Border Collie                            29
# Retriever                                28
# Terrier                                  28
# Husky                                    25
# Boxer                                    19
# Catahoula Leopard Dog                    19
# Plott Hound                              14
# Australian Shepherd                      14
# Pug                                      13
# Schnauzer                                 9
# Jack Russell Terrier                      9
# Pit Bull Terrier                          8
# Poodle                                    7
# Flat-Coated Retriever                     6
# Basset Hound                              6
# Corgi                                     5
# Golden Retriever                          5
# Airedale Terrier                          5
# Schipperke                                4
# Pomeranian                                4
# Pointer                                   4
# Shetland Sheepdog / Sheltie               3
# Yorkshire Terrier                         3
# Anatolian Shepherd                        3
# English Bulldog                           2
# German Shepherd Dog                       2
# Shar-Pei                                  2
# Schnoodle                                 2
# Chiweenie                                 2
# Rat Terrier                               2
# Beagle                                    2
# Shih Tzu                                  2
# Great Dane                                2
# Wheaten Terrier                           2
# Vizsla                                    1
# West Highland White Terrier / Westie      1
# Tibetan Spaniel                           1
# Spaniel                                   1
# Whippet                                   1
# Wirehaired Dachshund                      1
# Miniature Schnauzer                       1
# Boston Terrier                            1
# Black Mouth Cur                           1
# Norfolk Terrier                           1
# Bull Terrier                              1
# Rhodesian Ridgeback                       1
# Lhasa Apso                                1
# Maltese                                   1
# American Bulldog                          1
# Pharaoh Hound                             1
# Papillon                                  1
# Mastiff                                   1

# %%
dog_breeds_count.max()
# Out:
# breeds.primary    77
# dtype: int64

# %%
# First create a dataframe grouping by the Breed Column
dogs_status = pet_data.groupby("status")

dogs_status_count = dogs_status["status"].size()

status_summary = pd.DataFrame({"Status": dogs_status_count})


status_summary
# Out:
#            Status
# status
# adoptable       7
# adopted       661

# %%
#Group by breed
breed_count = pet_data.groupby(["status","breeds.primary"]).size()

breed_status_summary = pd.DataFrame({"Count": breed_count})

breed_status_summary.sort_values(["status","Count"], ascending = False)
# Out:
#                               Count
# status    breeds.primary
# adopted   Chihuahua              77
#           Labrador Retriever     68
#           Collie                 44
#           Great Pyrenees         41
#           Dachshund              36
# ...                             ...
# adoptable Collie                  1
#           Great Pyrenees          1
#           Hound                   1
#           Shepherd                1
#           Terrier                 1
#
# [66 rows x 1 columns]

# %%
#CSV Output for Breed Types by Status
output_data_file_breed_count ="/users/rebeccatast/desktop/Animal-Adoptions/breed_counts.csv"
breed_count.to_csv(output_data_file_breed_count, index_label="breeds.primary")

# %%
#Top 5 Breeds for Adopted and Adoptable
top_five_breeds = breed_count.sort_values(by = ["id.1","status"], ascending =[False, False])
top_five_breeds.head(25)
# Out:
#                                                id.1  organization_id  age  \
# status    breeds.primary
# adopted   Labrador Retriever                    622              622  622
#           Chihuahua                             560              560  560
#           Terrier                               453              453  453
#           Pit Bull Terrier                      328              328  328
#           Dachshund                             292              292  292
#           Australian Cattle Dog / Blue Heeler   234              234  234
#           German Shepherd Dog                   223              223  223
#           Shepherd                              222              222  222
# adoptable Labrador Retriever                    193              193  193
#           Pit Bull Terrier                      187              187  187
# adopted   Mixed Breed                           170              170  170
#           Boxer                                 156              156  156
#           Border Collie                         125              125  125
#           Great Pyrenees                        114              114  114
#           Hound                                 114              114  114
# adoptable Shepherd                              111              111  111
#           Terrier                               109              109  109
#           American Staffordshire Terrier        107              107  107
# adopted   Great Dane                            104              104  104
#           Husky                                  94               94   94
# adoptable Chihuahua                              93               93   93
# adopted   Jack Russell Terrier                   92               92   92
# adoptable Mixed Breed                            90               90   90
# adopted   Schnauzer                              86               86   86
#           Australian Shepherd                    85               85   85
#
#                                                gender  size  coat  tags  \
# status    breeds.primary
# adopted   Labrador Retriever                      622   622   513   622
#           Chihuahua                               560   560   421   560
#           Terrier                                 453   453   284   453
#           Pit Bull Terrier                        328   328   312   328
#           Dachshund                               292   292   168   292
#           Australian Cattle Dog / Blue Heeler     234   234   206   234
#           German Shepherd Dog                     223   223   196   223
#           Shepherd                                222   222   196   222
# adoptable Labrador Retriever                      193   193    35   193
#           Pit Bull Terrier                        187   187    31   187
# adopted   Mixed Breed                             170   170   133   170
#           Boxer                                   156   156   134   156
#           Border Collie                           125   125   112   125
#           Great Pyrenees                          114   114   106   114
#           Hound                                   114   114   102   114
# adoptable Shepherd                                111   111    16   111
#           Terrier                                 109   109    37   109
#           American Staffordshire Terrier          107   107     7   107
# adopted   Great Dane                              104   104    43   104
#           Husky                                    94    94    75    94
# adoptable Chihuahua                                93    93    21    93
# adopted   Jack Russell Terrier                     92    92    75    92
# adoptable Mixed Breed                              90    90    21    90
# adopted   Schnauzer                                86    86    56    86
#           Australian Shepherd                      85    85    72    85
#
#                                                name_x  description  \
# status    breeds.primary
# adopted   Labrador Retriever                      622          590
#           Chihuahua                               560          507
#           Terrier                                 453          423
#           Pit Bull Terrier                        328          217
#           Dachshund                               292          287
#           Australian Cattle Dog / Blue Heeler     234          205
#           German Shepherd Dog                     223          218
#           Shepherd                                222          208
# adoptable Labrador Retriever                      193          100
#           Pit Bull Terrier                        187          120
# adopted   Mixed Breed                             170          121
#           Boxer                                   156          145
#           Border Collie                           125          118
#           Great Pyrenees                          114          109
#           Hound                                   114           93
# adoptable Shepherd                                111           78
#           Terrier                                 109           81
#           American Staffordshire Terrier          107           37
# adopted   Great Dane                              104          101
#           Husky                                    94           88
# adoptable Chihuahua                                93           61
# adopted   Jack Russell Terrier                     92           88
# adoptable Mixed Breed                              90           43
# adopted   Schnauzer                                86           75
#           Australian Shepherd                      85           82
#
#                                                status_changed_at  ...  \
# status    breeds.primary                                          ...
# adopted   Labrador Retriever                                 622  ...
#           Chihuahua                                          560  ...
#           Terrier                                            453  ...
#           Pit Bull Terrier                                   328  ...
#           Dachshund                                          292  ...
#           Australian Cattle Dog / Blue Heeler                234  ...
#           German Shepherd Dog                                223  ...
#           Shepherd                                           222  ...
# adoptable Labrador Retriever                                 193  ...
#           Pit Bull Terrier                                   187  ...
# adopted   Mixed Breed                                        170  ...
#           Boxer                                              156  ...
#           Border Collie                                      125  ...
#           Great Pyrenees                                     114  ...
#           Hound                                              114  ...
# adoptable Shepherd                                           111  ...
#           Terrier                                            109  ...
#           American Staffordshire Terrier                     107  ...
# adopted   Great Dane                                         104  ...
#           Husky                                               94  ...
# adoptable Chihuahua                                           93  ...
# adopted   Jack Russell Terrier                                92  ...
# adoptable Mixed Breed                                         90  ...
# adopted   Schnauzer                                           86  ...
#           Australian Shepherd                                 85  ...
#
#                                                colors.primary  \
# status    breeds.primary
# adopted   Labrador Retriever                              533
#           Chihuahua                                       417
#           Terrier                                         288
#           Pit Bull Terrier                                301
#           Dachshund                                       168
#           Australian Cattle Dog / Blue Heeler             205
#           German Shepherd Dog                             130
#           Shepherd                                        198
# adoptable Labrador Retriever                               61
#           Pit Bull Terrier                                 61
# adopted   Mixed Breed                                     142
#           Boxer                                           130
#           Border Collie                                   108
#           Great Pyrenees                                  101
#           Hound                                            88
# adoptable Shepherd                                         59
#           Terrier                                          51
#           American Staffordshire Terrier                   23
# adopted   Great Dane                                       50
#           Husky                                            78
# adoptable Chihuahua                                        46
# adopted   Jack Russell Terrier                             77
# adoptable Mixed Breed                                      31
# adopted   Schnauzer                                        52
#           Australian Shepherd                              74
#
#                                                attributes.spayed_neutered  \
# status    breeds.primary
# adopted   Labrador Retriever                                          622
#           Chihuahua                                                   560
#           Terrier                                                     453
#           Pit Bull Terrier                                            328
#           Dachshund                                                   292
#           Australian Cattle Dog / Blue Heeler                         234
#           German Shepherd Dog                                         223
#           Shepherd                                                    222
# adoptable Labrador Retriever                                          193
#           Pit Bull Terrier                                            187
# adopted   Mixed Breed                                                 170
#           Boxer                                                       156
#           Border Collie                                               125
#           Great Pyrenees                                              114
#           Hound                                                       114
# adoptable Shepherd                                                    111
#           Terrier                                                     109
#           American Staffordshire Terrier                              107
# adopted   Great Dane                                                  104
#           Husky                                                        94
# adoptable Chihuahua                                                    93
# adopted   Jack Russell Terrier                                         92
# adoptable Mixed Breed                                                  90
# adopted   Schnauzer                                                    86
#           Australian Shepherd                                          85
#
#                                                attributes.house_trained  \
# status    breeds.primary
# adopted   Labrador Retriever                                        622
#           Chihuahua                                                 560
#           Terrier                                                   453
#           Pit Bull Terrier                                          328
#           Dachshund                                                 292
#           Australian Cattle Dog / Blue Heeler                       234
#           German Shepherd Dog                                       223
#           Shepherd                                                  222
# adoptable Labrador Retriever                                        193
#           Pit Bull Terrier                                          187
# adopted   Mixed Breed                                               170
#           Boxer                                                     156
#           Border Collie                                             125
#           Great Pyrenees                                            114
#           Hound                                                     114
# adoptable Shepherd                                                  111
#           Terrier                                                   109
#           American Staffordshire Terrier                            107
# adopted   Great Dane                                                104
#           Husky                                                      94
# adoptable Chihuahua                                                  93
# adopted   Jack Russell Terrier                                       92
# adoptable Mixed Breed                                                90
# adopted   Schnauzer                                                  86
#           Australian Shepherd                                        85
#
#                                                attributes.special_needs  \
# status    breeds.primary
# adopted   Labrador Retriever                                        622
#           Chihuahua                                                 560
#           Terrier                                                   453
#           Pit Bull Terrier                                          328
#           Dachshund                                                 292
#           Australian Cattle Dog / Blue Heeler                       234
#           German Shepherd Dog                                       223
#           Shepherd                                                  222
# adoptable Labrador Retriever                                        193
#           Pit Bull Terrier                                          187
# adopted   Mixed Breed                                               170
#           Boxer                                                     156
#           Border Collie                                             125
#           Great Pyrenees                                            114
#           Hound                                                     114
# adoptable Shepherd                                                  111
#           Terrier                                                   109
#           American Staffordshire Terrier                            107
# adopted   Great Dane                                                104
#           Husky                                                      94
# adoptable Chihuahua                                                  93
# adopted   Jack Russell Terrier                                       92
# adoptable Mixed Breed                                                90
# adopted   Schnauzer                                                  86
#           Australian Shepherd                                        85
#
#                                                attributes.shots_current  \
# status    breeds.primary
# adopted   Labrador Retriever                                        622
#           Chihuahua                                                 560
#           Terrier                                                   453
#           Pit Bull Terrier                                          328
#           Dachshund                                                 292
#           Australian Cattle Dog / Blue Heeler                       234
#           German Shepherd Dog                                       223
#           Shepherd                                                  222
# adoptable Labrador Retriever                                        193
#           Pit Bull Terrier                                          187
# adopted   Mixed Breed                                               170
#           Boxer                                                     156
#           Border Collie                                             125
#           Great Pyrenees                                            114
#           Hound                                                     114
# adoptable Shepherd                                                  111
#           Terrier                                                   109
#           American Staffordshire Terrier                            107
# adopted   Great Dane                                                104
#           Husky                                                      94
# adoptable Chihuahua                                                  93
# adopted   Jack Russell Terrier                                       92
# adoptable Mixed Breed                                                90
# adopted   Schnauzer                                                  86
#           Australian Shepherd                                        85
#
#                                                contact.address.city  \
# status    breeds.primary
# adopted   Labrador Retriever                                    622
#           Chihuahua                                             560
#           Terrier                                               453
#           Pit Bull Terrier                                      328
#           Dachshund                                             292
#           Australian Cattle Dog / Blue Heeler                   234
#           German Shepherd Dog                                   223
#           Shepherd                                              222
# adoptable Labrador Retriever                                    193
#           Pit Bull Terrier                                      187
# adopted   Mixed Breed                                           170
#           Boxer                                                 156
#           Border Collie                                         125
#           Great Pyrenees                                        114
#           Hound                                                 114
# adoptable Shepherd                                              111
#           Terrier                                               109
#           American Staffordshire Terrier                        107
# adopted   Great Dane                                            104
#           Husky                                                  94
# adoptable Chihuahua                                              93
# adopted   Jack Russell Terrier                                   92
# adoptable Mixed Breed                                            90
# adopted   Schnauzer                                              86
#           Australian Shepherd                                    85
#
#                                                contact.address.postcode  \
# status    breeds.primary
# adopted   Labrador Retriever                                        622
#           Chihuahua                                                 560
#           Terrier                                                   453
#           Pit Bull Terrier                                          328
#           Dachshund                                                 292
#           Australian Cattle Dog / Blue Heeler                       234
#           German Shepherd Dog                                       223
#           Shepherd                                                  222
# adoptable Labrador Retriever                                        193
#           Pit Bull Terrier                                          187
# adopted   Mixed Breed                                               170
#           Boxer                                                     156
#           Border Collie                                             125
#           Great Pyrenees                                            114
#           Hound                                                     114
# adoptable Shepherd                                                  111
#           Terrier                                                   109
#           American Staffordshire Terrier                            107
# adopted   Great Dane                                                104
#           Husky                                                      94
# adoptable Chihuahua                                                  93
# adopted   Jack Russell Terrier                                       92
# adoptable Mixed Breed                                                90
# adopted   Schnauzer                                                  86
#           Australian Shepherd                                        85
#
#                                                animal_id  organization_id.1  \
# status    breeds.primary
# adopted   Labrador Retriever                         622                622
#           Chihuahua                                  560                560
#           Terrier                                    453                453
#           Pit Bull Terrier                           328                328
#           Dachshund                                  292                292
#           Australian Cattle Dog / Blue Heeler        234                234
#           German Shepherd Dog                        223                223
#           Shepherd                                   222                222
# adoptable Labrador Retriever                         193                193
#           Pit Bull Terrier                           187                187
# adopted   Mixed Breed                                170                170
#           Boxer                                      156                156
#           Border Collie                              125                125
#           Great Pyrenees                             114                114
#           Hound                                      114                114
# adoptable Shepherd                                   111                111
#           Terrier                                    109                109
#           American Staffordshire Terrier             107                107
# adopted   Great Dane                                 104                104
#           Husky                                       94                 94
# adoptable Chihuahua                                   93                 93
# adopted   Jack Russell Terrier                        92                 92
# adoptable Mixed Breed                                 90                 90
# adopted   Schnauzer                                   86                 86
#           Australian Shepherd                         85                 85
#
#                                                name_y
# status    breeds.primary
# adopted   Labrador Retriever                      622
#           Chihuahua                               560
#           Terrier                                 453
#           Pit Bull Terrier                        328
#           Dachshund                               292
#           Australian Cattle Dog / Blue Heeler     234
#           German Shepherd Dog                     223
#           Shepherd                                222
# adoptable Labrador Retriever                      193
#           Pit Bull Terrier                        187
# adopted   Mixed Breed                             170
#           Boxer                                   156
#           Border Collie                           125
#           Great Pyrenees                          114
#           Hound                                   114
# adoptable Shepherd                                111
#           Terrier                                 109
#           American Staffordshire Terrier          107
# adopted   Great Dane                              104
#           Husky                                    94
# adoptable Chihuahua                                93
# adopted   Jack Russell Terrier                     92
# adoptable Mixed Breed                              90
# adopted   Schnauzer                                86
#           Australian Shepherd                      85
#
# [25 rows x 22 columns]

# %%
# Count of Spayed vs Neutered
fixed_status = pet_shelter.groupby("attributes.spayed_neutered")

fixed_status_count = pd.DataFrame(fixed_status["attributes.spayed_neutered"].count())

print(fixed_status_count)
# Out:
#                             attributes.spayed_neutered
# attributes.spayed_neutered
# False                                             1620
# True                                              5858

# %%
#Fixed by Status
group_fixed = pet_data.groupby(["status","attributes.spayed_neutered"]).size()


group_fixed_summary = pd.DataFrame({"Count": group_fixed})

group_fixed_summary.sort_values(["status","Count"], ascending = False)
# Out:
#                                       Count
# status    attributes.spayed_neutered
# adopted   True                          657
#           False                           4
# adoptable True                            7

# %%
true_spayed1 = pet_data.loc[:, "attributes.spayed_neutered"]
true_spayed2 = true_spayed1.value_counts()
true_spayed2
# Out:
# True     664
# False      4
# Name: attributes.spayed_neutered, dtype: int64

# %%
colors = ["green", "tomato"]
explode = [0, 0.2]

labels = ['Spayed/Neutered', 'Intact']
true_spayed2.plot(kind="pie",shadow = True, colors=colors, labels = labels, explode = explode, startangle=45,figsize=(6,4), autopct='%1.1f%%')
#plt.title("Spayed/Neuter vs Intact")
plt.ylabel(" ")
plt.axis("equal")
plt.show()


plt.savefig("Animal-Adoptions/output_data/LargestShelter_Fixed.png")

# %%
#Pie Chart Using Pyplot Fixed Adoptable
Spayed_Neutered = ["True", "False"]
numbers = [1165,489]
colors = ["steelblue","darkorange"]
explode = (0,0)

#Create Pie Chart Using the Above Data
plt.ylabel("Adoptable Dogs Spayed or Neutered")
plt.pie(numbers, explode=explode, labels=Spayed_Neutered, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.show()

# %%
#Pie Chart Using Pyplot Fixed Adopted

Spayed_Neutered = ["True", "False"]
numbers = [4693,1131]
colors = ["steelblue","darkorange"]
explode = (0,0)

#Create Pie Chart Using the Above Data
plt.ylabel("Adopted Dogs Spayed or Neutered")
plt.pie(numbers, explode=explode, labels=Spayed_Neutered, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)

# Create axes which are equal so we have a perfect circle
plt.axis("equal")
plt.show()

# %%
#Age Overall
SA_Shelter.groupby("age").size()
# Out:
# age
# Adult     2902
# Baby      2140
# Senior     402
# Young     2034
# dtype: int64

# %%
#Age by Status
group_age = SA_Shelter.groupby(["age","status"]).size()
print(group_age)
# Out:
# age     status
# Adult   adoptable     899
#         adopted      2003
# Baby    adoptable     150
#         adopted      1990
# Senior  adoptable     140
#         adopted       262
# Young   adoptable     465
#         adopted      1569
# dtype: int64

# %%
#Age by Status Bar Graphs
status_age = pd.DataFrame({
    "Adoptable":[150, 465, 899, 140],
    "Adopted":[1990, 1569, 2003, 262]
    }, 
    index=["Baby", "Young", "Adult", "Senior"]
)
status_age.head()
# Out:
#         Adoptable  Adopted
# Baby          150     1990
# Young         465     1569
# Adult         899     2003
# Senior        140      262

# %%
plotdata = pd.DataFrame({
    "Adoptable":[150, 465, 899, 140],
    "Adopted":[1990, 1569, 2003, 262]
    },  
    index=["Baby", "Young", "Adult", "Senior"]
)
plotdata.plot(kind="bar")
plt.title("Dog Age and Status")
plt.xlabel("Dog Ages")
plt.ylabel("Number of Dogs")
# Out:
# Text(0, 0.5, 'Number of Dogs')

# %%
#Size Overall
SA_Shelter.groupby("size").size()
# Out:
# size
# Extra Large     113
# Large          1320
# Medium         3742
# Small          2303
# dtype: int64

# %%
#Size by Status
group_size_status = SA_Shelter.groupby(["size", "status"]).size()
print(group_size_status)
# Out:
# size         status
# Extra Large  adoptable      26
#              adopted        87
# Large        adoptable     405
#              adopted       915
# Medium       adoptable     852
#              adopted      2890
# Small        adoptable     371
#              adopted      1932
# dtype: int64

# %%
status_size = pd.DataFrame({
    "Adoptable":[26, 405, 852, 371],
    "Adopted":[87, 915, 2890, 1932]
    }, 
    index=["Extra Large", "Large", "Medium", "Small"]
)
status_size.head()
# Out:
#              Adoptable  Adopted
# Extra Large         26       87
# Large              405      915
# Medium             852     2890
# Small              371     1932

# %%
plotdata = pd.DataFrame({
    "adoptable":[26, 405, 852, 371],
    "adopted":[87, 915, 2890, 1932]
    }, 
    index=["Extra Large", "Large", "Medium", "Small"]
)
plotdata.plot(kind="bar")
plt.title("Dog Size and Status")
plt.xlabel("Dog Sizes")
plt.ylabel("Number of Dogs")
# Out:
# Text(0, 0.5, 'Number of Dogs')
